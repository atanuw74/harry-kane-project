# %%
import json
import io
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from copy import deepcopy
from urllib.request import urlopen

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Scrape PL stats:
pl_scrape_url = "https://understat.com/league/EPL/2020"
page_connect = urlopen(pl_scrape_url)
page_html = BeautifulSoup(page_connect, "html.parser")

json_raw_string = page_html.findAll(name="script")[3].text
start_ind = json_raw_string.index("\\")
stop_ind = json_raw_string.index("')")

json_data = json_raw_string[start_ind:stop_ind]
json_data = json_data.encode("utf8").decode("unicode_escape")

pl_top_df = pd.json_normalize(json.loads(json_data))

# %%
pl_top_df
# Out:
#        id      player_name  ...             xGChain           xGBuildup
# 0     647       Harry Kane  ...  24.995648321695626   4.451256847940385
# 1    1250    Mohamed Salah  ...  28.968233548104763   9.800235655158758
# 2    1228  Bruno Fernandes  ...  26.911412378773093   11.93228487111628
# 3     453    Son Heung-Min  ...    20.6719155497849   6.608751138672233
# 4     822  Patrick Bamford  ...  23.394952706992626   4.131795546039939
# ..    ...              ...  ...                 ...                 ...
# 519  9423  Gaetano Berardi  ...  0.2312779352068901  0.2312779352068901
# 520  9540      Femi Seriki  ...                   0                   0
# 521  9552  Tyrese Francois  ...                   0                   0
# 522  9557     William Fish  ...                   0                   0
# 523  9558  Hannibal Mejbri  ...                   0                   0
#
# [524 rows x 18 columns]

# %%
# Scrape LaLiga stats:
spain_scrape_url = "https://understat.com/league/La_liga/2020"
page_connect = urlopen(spain_scrape_url)
page_html = BeautifulSoup(page_connect, "html.parser")

json_raw_string = page_html.findAll(name="script")[3].text
start_ind = json_raw_string.index("\\")
stop_ind = json_raw_string.index("')")

json_data = json_raw_string[start_ind:stop_ind]
json_data = json_data.encode("utf8").decode("unicode_escape")

spain_top_df = pd.json_normalize(json.loads(json_data))

# %%
spain_top_df
# Out:
#        id        player_name  ...              xGChain             xGBuildup
# 0    2097       Lionel Messi  ...   37.906863175332546     20.33736250922084
# 1    2120      Gerard Moreno  ...    23.26353019475937     6.951297817751765
# 2    2370      Karim Benzema  ...   28.303930163383484     6.194142518565059
# 3    2098        Luis Suárez  ...   18.595971453934908    1.2328046094626188
# 4    5169  Youssef En-Nesyri  ...    17.81611675210297     1.087053531780839
# ..    ...                ...  ...                  ...                   ...
# 565  9457        José Boacho  ...  0.03350281435996294  0.014886233024299145
# 566  9496  Alejandro Cantero  ...   1.4155199863016605    0.3262682557106018
# 567  9519   Carlos Domínguez  ...   0.2482907883822918    0.2482907883822918
# 568  9520        Hugo Sotelo  ...                    0                     0
# 569  9534     Álvaro Bastida  ...                    0                     0
#
# [570 rows x 18 columns]

# %% [markdown]
# ***JOINT PL LALIGA STATS***

# %%
joint_df = pl_top_df.append(spain_top_df)
joint_df
# Out:
#        id        player_name  ...              xGChain             xGBuildup
# 0     647         Harry Kane  ...   24.995648321695626     4.451256847940385
# 1    1250      Mohamed Salah  ...   28.968233548104763     9.800235655158758
# 2    1228    Bruno Fernandes  ...   26.911412378773093     11.93228487111628
# 3     453      Son Heung-Min  ...     20.6719155497849     6.608751138672233
# 4     822    Patrick Bamford  ...   23.394952706992626     4.131795546039939
# ..    ...                ...  ...                  ...                   ...
# 565  9457        José Boacho  ...  0.03350281435996294  0.014886233024299145
# 566  9496  Alejandro Cantero  ...   1.4155199863016605    0.3262682557106018
# 567  9519   Carlos Domínguez  ...   0.2482907883822918    0.2482907883822918
# 568  9520        Hugo Sotelo  ...                    0                     0
# 569  9534     Álvaro Bastida  ...                    0                     0
#
# [1094 rows x 18 columns]

# %%
joint_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094 entries, 0 to 569
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1094 non-null   object
#  1   player_name   1094 non-null   object
#  2   games         1094 non-null   object
#  3   time          1094 non-null   object
#  4   goals         1094 non-null   object
#  5   xG            1094 non-null   object
#  6   assists       1094 non-null   object
#  7   xA            1094 non-null   object
#  8   shots         1094 non-null   object
#  9   key_passes    1094 non-null   object
#  10  yellow_cards  1094 non-null   object
#  11  red_cards     1094 non-null   object
#  12  position      1094 non-null   object
#  13  team_title    1094 non-null   object
#  14  npg           1094 non-null   object
#  15  npxG          1094 non-null   object
#  16  xGChain       1094 non-null   object
#  17  xGBuildup     1094 non-null   object
# dtypes: object(18)
# memory usage: 162.4+ KB

# %%
joint_df = joint_df.apply(pd.to_numeric, errors="ignore")

# %%
joint_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094 entries, 0 to 569
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1094 non-null   int64
#  1   player_name   1094 non-null   object
#  2   games         1094 non-null   int64
#  3   time          1094 non-null   int64
#  4   goals         1094 non-null   int64
#  5   xG            1094 non-null   float64
#  6   assists       1094 non-null   int64
#  7   xA            1094 non-null   float64
#  8   shots         1094 non-null   int64
#  9   key_passes    1094 non-null   int64
#  10  yellow_cards  1094 non-null   int64
#  11  red_cards     1094 non-null   int64
#  12  position      1094 non-null   object
#  13  team_title    1094 non-null   object
#  14  npg           1094 non-null   int64
#  15  npxG          1094 non-null   float64
#  16  xGChain       1094 non-null   float64
#  17  xGBuildup     1094 non-null   float64
# dtypes: float64(5), int64(10), object(3)
# memory usage: 162.4+ KB

# %% [markdown]
# ***REQUIRED DATA***

# %%
top = deepcopy(joint_df[joint_df["goals"] > 9])

# %%
top
# Out:
#       id                player_name  games  ...       npxG    xGChain  xGBuildup
# 0    647                 Harry Kane     35  ...  19.130183  24.995648   4.451257
# 1   1250              Mohamed Salah     37  ...  15.683834  28.968234   9.800236
# 2   1228            Bruno Fernandes     37  ...   8.407840  26.911412  11.932285
# 3    453              Son Heung-Min     37  ...  10.262118  20.671916   6.608751
# 4    822            Patrick Bamford     38  ...  16.879525  23.394953   4.131796
# 5   5555      Dominic Calvert-Lewin     33  ...  18.210514  19.884306   4.270798
# 6    755                Jamie Vardy     34  ...  13.092427  18.227907   2.412588
# 7   8865              Ollie Watkins     37  ...  14.757840  22.014021   5.334991
# 8    314             Ilkay Gündogan     28  ...   8.044545  19.286812  10.148375
# 9   3277        Alexandre Lacazette     31  ...   9.745403  14.361542   2.937941
# 10   468              Callum Wilson     26  ...  10.545416  14.205593   1.052545
# 11   620          Kelechi Iheanacho     25  ...   8.287427  13.961564   3.429915
# 12   986                 Danny Ings     29  ...   6.754236  10.482218   2.479041
# 13  4456                 Chris Wood     33  ...  11.431798  13.585282   2.149852
# 14   522              Wilfried Zaha     30  ...   7.282102  13.579472   3.634436
# 15   556            Marcus Rashford     37  ...   9.579710  20.441910   8.927208
# 16   838                 Sadio Mané     35  ...  14.828548  24.998923   6.057656
# 17  2251                Gareth Bale     20  ...   5.797858   8.149641   2.594514
# 18  7153            Matheus Pereira     33  ...   3.903641  10.857054   3.757924
# 19   318  Pierre-Emerick Aubameyang     29  ...   8.927714  15.113904   3.955129
# 20   531            Michail Antonio     26  ...  14.138839  19.273826   2.770521
# 21   606          Christian Benteke     30  ...   7.457401   8.472840   3.153554
# 22   618            Raheem Sterling     31  ...  11.289505  25.883725  12.173159
# 23  3294             Edinson Cavani     26  ...   8.603232  12.259187   2.730645
# 24  5612             Anwar El Ghazi     28  ...   5.992842   7.845563   2.691346
# 25  5656               Nicolas Pepe     29  ...   5.239038   9.359740   4.217726
# 26  8288               Tomas Soucek     38  ...   8.982983  16.998435   8.716958
# 0   2097               Lionel Messi     35  ...  22.960455  37.906863  20.337363
# 1   2120              Gerard Moreno     33  ...  12.095480  23.263530   6.951298
# 2   2370              Karim Benzema     34  ...  18.711244  28.303930   6.194143
# 3   2098                Luis Suárez     32  ...  15.662633  18.595971   1.232805
# 4   5169          Youssef En-Nesyri     38  ...  15.794806  17.816117   1.087054
# 5   5232             Alexander Isak     34  ...  15.724410  17.613967   2.982304
# 6   2186                    Morales     38  ...   7.061445  12.581370   3.269994
# 7   2290                 Iago Aspas     33  ...   8.539055  25.359111  11.444090
# 8   2270          Antoine Griezmann     36  ...  10.942391  24.722414  12.167519
# 9   2589                   Rafa Mir     38  ...  12.880270  13.065967   2.035372
# 10  2384                 Santi Mina     34  ...   8.613029  14.686006   5.218658
# 11  2518            Marcos Llorente     37  ...   4.768966  19.449846  10.456970
# 12  2566                      Roger     33  ...   6.571263  12.849092   4.277771
# 13  5074                Kike García     37  ...  10.610246  14.646081   4.451285
# 14   866                     Joselu     37  ...   9.180282  10.710237   1.154143
# 15  1235               Ante Budimir     30  ...   9.928603   9.380050   0.958334
# 16  2234            Mikel Oyarzabal     33  ...   5.639075  18.715211   9.977227
# 17  2478               Carlos Soler     32  ...   2.720083   9.745374   5.717745
# 18  2543             Borja Iglesias     28  ...   5.232592   6.357376   2.430538
#
# [46 rows x 18 columns]

# %%
top.reset_index(drop=True, inplace=True)

# %%
top
# Out:
#       id                player_name  games  ...       npxG    xGChain  xGBuildup
# 0    647                 Harry Kane     35  ...  19.130183  24.995648   4.451257
# 1   1250              Mohamed Salah     37  ...  15.683834  28.968234   9.800236
# 2   1228            Bruno Fernandes     37  ...   8.407840  26.911412  11.932285
# 3    453              Son Heung-Min     37  ...  10.262118  20.671916   6.608751
# 4    822            Patrick Bamford     38  ...  16.879525  23.394953   4.131796
# 5   5555      Dominic Calvert-Lewin     33  ...  18.210514  19.884306   4.270798
# 6    755                Jamie Vardy     34  ...  13.092427  18.227907   2.412588
# 7   8865              Ollie Watkins     37  ...  14.757840  22.014021   5.334991
# 8    314             Ilkay Gündogan     28  ...   8.044545  19.286812  10.148375
# 9   3277        Alexandre Lacazette     31  ...   9.745403  14.361542   2.937941
# 10   468              Callum Wilson     26  ...  10.545416  14.205593   1.052545
# 11   620          Kelechi Iheanacho     25  ...   8.287427  13.961564   3.429915
# 12   986                 Danny Ings     29  ...   6.754236  10.482218   2.479041
# 13  4456                 Chris Wood     33  ...  11.431798  13.585282   2.149852
# 14   522              Wilfried Zaha     30  ...   7.282102  13.579472   3.634436
# 15   556            Marcus Rashford     37  ...   9.579710  20.441910   8.927208
# 16   838                 Sadio Mané     35  ...  14.828548  24.998923   6.057656
# 17  2251                Gareth Bale     20  ...   5.797858   8.149641   2.594514
# 18  7153            Matheus Pereira     33  ...   3.903641  10.857054   3.757924
# 19   318  Pierre-Emerick Aubameyang     29  ...   8.927714  15.113904   3.955129
# 20   531            Michail Antonio     26  ...  14.138839  19.273826   2.770521
# 21   606          Christian Benteke     30  ...   7.457401   8.472840   3.153554
# 22   618            Raheem Sterling     31  ...  11.289505  25.883725  12.173159
# 23  3294             Edinson Cavani     26  ...   8.603232  12.259187   2.730645
# 24  5612             Anwar El Ghazi     28  ...   5.992842   7.845563   2.691346
# 25  5656               Nicolas Pepe     29  ...   5.239038   9.359740   4.217726
# 26  8288               Tomas Soucek     38  ...   8.982983  16.998435   8.716958
# 27  2097               Lionel Messi     35  ...  22.960455  37.906863  20.337363
# 28  2120              Gerard Moreno     33  ...  12.095480  23.263530   6.951298
# 29  2370              Karim Benzema     34  ...  18.711244  28.303930   6.194143
# 30  2098                Luis Suárez     32  ...  15.662633  18.595971   1.232805
# 31  5169          Youssef En-Nesyri     38  ...  15.794806  17.816117   1.087054
# 32  5232             Alexander Isak     34  ...  15.724410  17.613967   2.982304
# 33  2186                    Morales     38  ...   7.061445  12.581370   3.269994
# 34  2290                 Iago Aspas     33  ...   8.539055  25.359111  11.444090
# 35  2270          Antoine Griezmann     36  ...  10.942391  24.722414  12.167519
# 36  2589                   Rafa Mir     38  ...  12.880270  13.065967   2.035372
# 37  2384                 Santi Mina     34  ...   8.613029  14.686006   5.218658
# 38  2518            Marcos Llorente     37  ...   4.768966  19.449846  10.456970
# 39  2566                      Roger     33  ...   6.571263  12.849092   4.277771
# 40  5074                Kike García     37  ...  10.610246  14.646081   4.451285
# 41   866                     Joselu     37  ...   9.180282  10.710237   1.154143
# 42  1235               Ante Budimir     30  ...   9.928603   9.380050   0.958334
# 43  2234            Mikel Oyarzabal     33  ...   5.639075  18.715211   9.977227
# 44  2478               Carlos Soler     32  ...   2.720083   9.745374   5.717745
# 45  2543             Borja Iglesias     28  ...   5.232592   6.357376   2.430538
#
# [46 rows x 18 columns]

# %%
top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            46 non-null     int64
#  1   player_name   46 non-null     object
#  2   games         46 non-null     int64
#  3   time          46 non-null     int64
#  4   goals         46 non-null     int64
#  5   xG            46 non-null     float64
#  6   assists       46 non-null     int64
#  7   xA            46 non-null     float64
#  8   shots         46 non-null     int64
#  9   key_passes    46 non-null     int64
#  10  yellow_cards  46 non-null     int64
#  11  red_cards     46 non-null     int64
#  12  position      46 non-null     object
#  13  team_title    46 non-null     object
#  14  npg           46 non-null     int64
#  15  npxG          46 non-null     float64
#  16  xGChain       46 non-null     float64
#  17  xGBuildup     46 non-null     float64
# dtypes: float64(5), int64(10), object(3)
# memory usage: 6.6+ KB

# %%
top["Goals_Per_90"] = top["goals"].divide(top["time"]).multiply(90)

# %%
top["Assists_Per_90"] = top["assists"].divide(top["time"]).multiply(90)

# %%
top["Shots_Per_90"] = top["shots"].divide(top["time"]).multiply(90)

# %%
top["Key_Passes_Per_90"] = top["key_passes"].divide(top["time"]).multiply(90)

# %%
top["xG_Per_90"] = top["xG"].divide(top["time"]).multiply(90)

# %%
top["xA_Per_90"] = top["xA"].divide(top["time"]).multiply(90)

# %%
top["npg_Per_90"] = top["npg"].divide(top["time"]).multiply(90)

# %%
top["npxG_Per_90"] = top["npxG"].divide(top["time"]).multiply(90)

# %%
top["xGChain_Per_90"] = top["xGChain"].divide(top["time"]).multiply(90)

# %%
top["xGBuildup_Per_90"] = top["xGBuildup"].divide(top["time"]).multiply(90)

# %%
per90_stats = ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"]

# %%
top.loc[(top["id"] == 647), per90_stats].sum()
# Out:
# Goals_Per_90         0.668389
# Assists_Per_90       0.406845
# Shots_Per_90         4.010333
# Key_Passes_Per_90    1.423959
# xG_Per_90            0.644410
# xA_Per_90            0.220193
# npg_Per_90           0.552147
# npxG_Per_90          0.555930
# xGChain_Per_90       0.726383
# xGBuildup_Per_90     0.129355
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
top[per90_stats] = scaler.fit_transform(top[per90_stats])

# %% [markdown]
# ***PLOTTING***

# %%
top_max = top[per90_stats].max().max()
top_max
# Out:
# 1.0000000000000002

# %%
import plotly.graph_objects as go

# %%
for i, row in top.iterrows():
    if row["id"] == 647:
        continue
    # Initiate the plotly go figure resembles a canvas
    fig = go.Figure()
    # Add Radar plots for different players:
    fig.add_trace(go.Scatterpolar(
        r=top.loc[(top["id"] == 647), per90_stats].sum(),
        theta=per90_stats,
        fill='toself',
        name='Harry Kane'))
    fig.add_trace(go.Scatterpolar(
        r=top.loc[(top["id"] == row["id"]), per90_stats].sum(),
        theta=per90_stats,
        fill='toself',
        name=row["player_name"]))
    # Additional properties for the plot:
    fig.update_layout(
        title="Harry Kane vs " + row["player_name"],
    polar=dict(
        radialaxis=dict(
        visible=True,
        range=[0, top_max]
        )),
    showlegend=True
    )
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0ae863b5-37f2-4e89-b4c8-b8ea7a5283c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ae863b5-37f2-4e89-b4c8-b8ea7a5283c9")) {
#                     Plotly.newPlot(
#                         '0ae863b5-37f2-4e89-b4c8-b8ea7a5283c9',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Mohamed Salah", "r": [0.4584501173378871, 0.35853206760824263, 0.5349213382192104, 0.5375530955783289, 0.6849855556997564, 0.5247245308211547, 0.35035564682356396, 0.6183272042138059, 0.6490809374003322, 0.43974943416982193], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9b9233ac-6a9a-4cf7-bbc5-521214708b9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9b9233ac-6a9a-4cf7-bbc5-521214708b9d")) {
#                     Plotly.newPlot(
#                         '9b9233ac-6a9a-4cf7-bbc5-521214708b9d',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Bruno Fernandes", "r": [0.31063902138370136, 0.8516430633851231, 0.4953666052481747, 1.0, 0.48793064341455994, 0.9701910380869596, 0.13436628878026702, 0.25780008219420236, 0.5654774596547364, 0.5421413212899792], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="31b4c102-33cf-48c3-ad6b-abf9ca53c4e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("31b4c102-33cf-48c3-ad6b-abf9ca53c4e4")) {
#                     Plotly.newPlot(
#                         '31b4c102-33cf-48c3-ad6b-abf9ca53c4e4',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Son Heung-Min", "r": [0.2715154718846948, 0.7047285304692124, 0.159983322584975, 0.7592659904998176, 0.2628366950169265, 0.7849576979318842, 0.3419733743962258, 0.3441846941140454, 0.33905072273385684, 0.27134197481330996], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="74d221c8-cd0a-412d-a497-f363214a53ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("74d221c8-cd0a-412d-a497-f363214a53ee")) {
#                     Plotly.newPlot(
#                         '74d221c8-cd0a-412d-a497-f363214a53ee',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Patrick Bamford", "r": [0.28184509353798015, 0.5019448946515398, 0.41452508233476565, 0.24130042353739894, 0.6021002921570955, 0.2713676036261229, 0.319901997345075, 0.6768793532345554, 0.4493700809009391, 0.15092727830590486], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="196e2954-8c19-4aba-9f20-00dd7d0e52d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("196e2954-8c19-4aba-9f20-00dd7d0e52d4")) {
#                     Plotly.newPlot(
#                         '196e2954-8c19-4aba-9f20-00dd7d0e52d4',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Dominic Calvert-Lewin", "r": [0.2871714716011602, 0.0, 0.30027391898851447, 0.11444087071486868, 0.6522371787255536, 0.1302868373129842, 0.385401681247732, 0.806196412553223, 0.3748193516609495, 0.17366129310974895], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b77463d1-157a-4009-8e6e-bbd970c1b219" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b77463d1-157a-4009-8e6e-bbd970c1b219")) {
#                     Plotly.newPlot(
#                         'b77463d1-157a-4009-8e6e-bbd970c1b219',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Jamie Vardy", "r": [0.2552923297770532, 0.6990619983948636, 0.2993485488095929, 0.24521162454468087, 0.7455778292546315, 0.43087854195062303, 0.09401248005817875, 0.5447800451289107, 0.31857066702196557, 0.07355864525130879], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8bb45558-6214-40b7-b791-a3aa350cfbdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8bb45558-6214-40b7-b791-a3aa350cfbdb")) {
#                     Plotly.newPlot(
#                         '8bb45558-6214-40b7-b791-a3aa350cfbdb',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ollie Watkins", "r": [0.13950038366442158, 0.3321535821535822, 0.3118067341027076, 0.3798185647889689, 0.45329661214393613, 0.37661265005653344, 0.22986710872173427, 0.5198117431531879, 0.34184834673434294, 0.19223365278313623], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2edbeba3-44c0-4c65-8870-d48547b4f276" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2edbeba3-44c0-4c65-8870-d48547b4f276")) {
#                     Plotly.newPlot(
#                         '2edbeba3-44c0-4c65-8870-d48547b4f276',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ilkay G\u00fcndogan", "r": [0.37816562988295654, 0.21762349799732977, 0.2557473964930102, 0.6410448061948898, 0.4279688075265158, 0.4566813877408533, 0.4176442810869051, 0.44808339016524296, 0.6597868787144084, 0.7250607489120999], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="33fa3122-6c27-4b8a-8c1a-7c04c8a52d7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("33fa3122-6c27-4b8a-8c1a-7c04c8a52d7d")) {
#                     Plotly.newPlot(
#                         '33fa3122-6c27-4b8a-8c1a-7c04c8a52d7d',
# ...
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a570657d-5099-4ffc-afcf-0fcf0eed5e08" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a570657d-5099-4ffc-afcf-0fcf0eed5e08")) {
#                     Plotly.newPlot(
#                         'a570657d-5099-4ffc-afcf-0fcf0eed5e08',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Carlos Soler", "r": [0.11804312975125414, 0.644704657819412, 0.0, 0.4851018028235413, 0.2512319937230122, 0.4700628245252143, 0.0, 0.0, 0.003510147557290344, 0.26782076590538156], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2d924ecb-22b4-499e-9cde-3c7e2ea4ddaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2d924ecb-22b4-499e-9cde-3c7e2ea4ddaf")) {
#                     Plotly.newPlot(
#                         '2d924ecb-22b4-499e-9cde-3c7e2ea4ddaf',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.49062336707243914, 1.0, 0.6075728049008011, 0.46420257929773967, 0.7673825106023461, 0.6187511953607353, 0.43947460879435707, 0.783462689487163, 0.5032582824092527, 0.16632588529154188], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Borja Iglesias", "r": [0.5296670618256345, 0.0, 0.2622258591034318, 0.041031101291470876, 0.6530309521962867, 0.052268635216111636, 0.26203359759295675, 0.4097412710066625, 0.10841647487441097, 0.2107860851529593], "theta": ["Goals_Per_90", "Assists_Per_90", "Shots_Per_90", "Key_Passes_Per_90", "xG_Per_90", "xA_Per_90", "npg_Per_90", "npxG_Per_90", "xGChain_Per_90", "xGBuildup_Per_90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1.0000000000000002], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinew ...
